# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['DJP', 'ZARUSD=X']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2015-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                   DJP  ZARUSD=X
# Date
# 2015-01-02  29.650000  0.086555
# 2015-01-05  29.690001  0.085268
# 2015-01-06  29.740000  0.085504
# 2015-01-07  29.549999  0.085324
# 2015-01-08  29.650000  0.085561

# %% [markdown]
# ## Normalization
# -start from the same point

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %% [markdown]
# ## Returns

# %%
returns=(ind_data/ind_data.shift(1))-1

# %%
#average annual returns
returns.mean() * 250
# Out:
# DJP        -0.100868
# ZARUSD=X   -0.050930
# dtype: float64

# %% [markdown]
# ## Correlation Returns

# %%
#correlation 
returns.corr()
# Out:
#               DJP  ZARUSD=X
# DJP       1.00000   0.15388
# ZARUSD=X  0.15388   1.00000

# %% [markdown]
# ## Correlation of Price

# %%
ind_data.corr()
# Out:
#                DJP  ZARUSD=X
# DJP       1.000000  0.836629
# ZARUSD=X  0.836629  1.000000

# %%
print("Correlation is :%.2f%%" %(ind_data.corr()["ZARUSD=X"].iloc[0]*100))
ind_data.corr()
# Out:
# Correclation is :83.66%
#                DJP  ZARUSD=X
# DJP       1.000000  0.836629
# ZARUSD=X  0.836629  1.000000
